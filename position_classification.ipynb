# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Standard Stats

# %%
# scrape data
url = "https://fbref.com/en/comps/Big5/2023-2024/stats/players/2023-2024-Big-5-European-Leagues-Stats"
df1 = pd.read_html(url)[0]

# %%
# create data frame and drop multi-level header
standard = pd.DataFrame(df1)
standard.columns = standard.columns.droplevel(0)

# %%
# filter out less than 1000 and na splitter rows
standard = standard[standard['Player'] != 'Player']
standard['Min'] = standard['Min'].astype(int)
standard = standard[standard['Min']>=1000]

# %%
# select certain columns
standard_df = standard[['Player', 'Nation', 'Pos', 'Squad', 'Min', '90s', 'Gls', 'Ast', 'PrgP', 'PrgC', 'PrgR']]
standard_df.head()
# Out:
#               Player   Nation    Pos         Squad   Min   90s Gls   Gls Ast  \
# 0         Max Aarons  eng ENG     DF   Bournemouth  1237  13.7   0  0.00   1
# 1   Brenden Aaronson   us USA  MF,FW  Union Berlin  1267  14.1   2  0.14   2
# 4   Yunis Abdelhamid   ma MAR     DF         Reims  2781  30.9   4  0.13   0
# 5  Salis Abdul Samed   gh GHA     MF          Lens  1519  16.9   0  0.00   0
# 7    Laurent Abergel   fr FRA     MF       Lorient  2860  31.8   2  0.06   1
#
#     Ast PrgP PrgC PrgR
# 0  0.07   43   22   26
# 1  0.14   56   37   91
# 4  0.00  137   36    9
# 5  0.00   78    9   20
# 7  0.03  194   38   51

# %% [markdown]
# #### Scoring Chances

# %%
# scrape data
url = "https://fbref.com/en/comps/Big5/2023-2024/gca/players/2023-2024-Big-5-European-Leagues-Stats"
df1x = pd.read_html(url)[0]

# %%
# create data frame and drop multi-level header
gca = pd.DataFrame(df1x)
gca.columns = gca.columns.droplevel(0)

# %%
# filter out na splitter rows
gca = gca[gca['Player'] != 'Player']

# %%
# select certain columns
gca_df = gca[['Player', 'Squad', 'SCA90', 'GCA90']]
gca_df.head()
# Out:
#               Player           Squad SCA90 GCA90
# 0         Max Aarons     Bournemouth  1.68  0.15
# 1   Brenden Aaronson    Union Berlin  3.76  0.57
# 2    Paxten Aaronson  Eint Frankfurt  0.89  0.89
# 3  Keyliane Abdallah       Marseille  0.00  0.00
# 4   Yunis Abdelhamid           Reims  0.78  0.03

# %% [markdown]
# ##### Defensive Actions

# %%
# scrape data
url = "https://fbref.com/en/comps/Big5/2023-2024/defense/players/2023-2024-Big-5-European-Leagues-Stats"
df2x = pd.read_html(url)[0]

# %%
# create data frame and drop multi-level header
defensive = pd.DataFrame(df2x)
defensive.columns = defensive.columns.droplevel(0)

# %%
# filter out na splitter rows
defensive = defensive[defensive['Player'] != 'Player']

# %%
# select certain columns
defensive_df = defensive[['Player', 'Squad', 'Tkl+Int', 'Blocks']]
defensive_df.head()
# Out:
#               Player           Squad Tkl+Int Blocks
# 0         Max Aarons     Bournemouth      37      9
# 1   Brenden Aaronson    Union Berlin      34     26
# 2    Paxten Aaronson  Eint Frankfurt       2      2
# 3  Keyliane Abdallah       Marseille       0      0
# 4   Yunis Abdelhamid           Reims     103     51

# %% [markdown]
# ##### Passing

# %%
# scrape data
url = "https://fbref.com/en/comps/Big5/2023-2024/passing/players/2023-2024-Big-5-European-Leagues-Stats"
df3x = pd.read_html(url)[0]

# %%
# create data frame and drop multi-level header
passing = pd.DataFrame(df3x)
passing.columns = passing.columns.droplevel(0)

# %%
# filter out na splitter rows
passing = passing[passing['Player'] != 'Player']

# %%
# select certain columns
passing_df = passing[['Player', 'Squad', 'Cmp', 'Cmp%', 'CrsPA', 'PPA']]
passing_df.head()
# Out:
#               Player           Squad   Cmp  Cmp  Cmp  Cmp   Cmp%   Cmp%  Cmp%  \
# 0         Max Aarons     Bournemouth   450  220  188   34   77.5   88.7  80.0
# 1   Brenden Aaronson    Union Berlin   365  206  105   19   77.3   85.8  80.8
# 2    Paxten Aaronson  Eint Frankfurt    41   20   20    0   82.0   80.0  90.9
# 3  Keyliane Abdallah       Marseille     1    1    0    0  100.0  100.0   NaN
# 4   Yunis Abdelhamid           Reims  1552  487  893  141   84.5   88.9  91.5
#
#    Cmp% CrsPA PPA
# 0  54.0     2  13
# 1  59.4     3  14
# 2   0.0     0   2
# 3   NaN     0   0
# 4  56.0     0   3

# %% [markdown]
# ##### Merge Data Together

# %%
# merge data together
player_df = standard_df.merge(gca_df, on=['Player', 'Squad'], how='left')
player_df = player_df.merge(defensive_df, on=['Player', 'Squad'], how='left')
player_df = player_df.merge(passing_df, on=['Player', 'Squad'], how='left')

player_df.head()
# Out:
#               Player   Nation    Pos         Squad   Min   90s Gls   Gls Ast  \
# 0         Max Aarons  eng ENG     DF   Bournemouth  1237  13.7   0  0.00   1
# 1   Brenden Aaronson   us USA  MF,FW  Union Berlin  1267  14.1   2  0.14   2
# 2   Yunis Abdelhamid   ma MAR     DF         Reims  2781  30.9   4  0.13   0
# 3  Salis Abdul Samed   gh GHA     MF          Lens  1519  16.9   0  0.00   0
# 4    Laurent Abergel   fr FRA     MF       Lorient  2860  31.8   2  0.06   1
#
#     Ast  ...   Cmp  Cmp  Cmp  Cmp  Cmp%  Cmp%  Cmp%  Cmp% CrsPA PPA
# 0  0.07  ...   450  220  188   34  77.5  88.7  80.0  54.0     2  13
# 1  0.14  ...   365  206  105   19  77.3  85.8  80.8  59.4     3  14
# 2  0.00  ...  1552  487  893  141  84.5  88.9  91.5  56.0     0   3
# 3  0.00  ...   796  393  330   41  88.9  90.8  91.7  75.9     2   5
# 4  0.03  ...  1551  629  711  150  84.5  89.0  88.7  64.4     3  23
#
# [5 rows x 27 columns]

# %%
# filter out GK
players = player_df[player_df['Pos'] != 'GK']
players.shape
# Out:
# (1415, 27)

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Squad', 'Min', '90s', 'Gls', 'gls90', 'Ast',
#        'ast90', 'PrgP', 'PrgC', 'PrgR', 'SCA90', 'GCA90', 'Tkl+Int', 'Blocks',
#        'passes', 'Cmp', 'Cmp', 'Cmp', 'pass%', 'Cmp%', 'Cmp%', 'Cmp%', 'CrsPA',
#        'PPA'],
#       dtype='object')

# %%
# rename some similar columns
players.columns.values[7] = 'gls90'
players.columns.values[9] = 'ast90'
players.columns.values[17] = 'passes'
players.columns.values[21] = 'pass%'

# drop the additional pass completion columns
players = players.drop(players[['Cmp', 'Cmp%']], axis=1)
players = players.drop(['Gls', 'Ast', 'Nation', 'Squad'], axis=1)

players.head()
# Out:
#               Player    Pos   Min   90s gls90 ast90 PrgP PrgC PrgR SCA90  \
# 0         Max Aarons     DF  1237  13.7  0.00  0.07   43   22   26  1.68
# 1   Brenden Aaronson  MF,FW  1267  14.1  0.14  0.14   56   37   91  3.76
# 2   Yunis Abdelhamid     DF  2781  30.9  0.13  0.00  137   36    9  0.78
# 3  Salis Abdul Samed     MF  1519  16.9  0.00  0.00   78    9   20  1.60
# 4    Laurent Abergel     MF  2860  31.8  0.06  0.03  194   38   51  2.55
#
#   GCA90 Tkl+Int Blocks passes pass% CrsPA PPA
# 0  0.15      37      9    450  77.5     2  13
# 1  0.57      34     26    365  77.3     3  14
# 2  0.03     103     51   1552  84.5     0   3
# 3  0.18      33     12    796  88.9     2   5
# 4  0.16     146     29   1551  84.5     3  23

# %%
# we will need to convert data types
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1415 entries, 0 to 1526
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   1415 non-null   object
#  1   Pos      1415 non-null   object
#  2   Min      1415 non-null   int32
#  3   90s      1415 non-null   object
#  4   gls90    1415 non-null   object
#  5   ast90    1415 non-null   object
#  6   PrgP     1415 non-null   object
#  7   PrgC     1415 non-null   object
#  8   PrgR     1415 non-null   object
#  9   SCA90    1415 non-null   object
#  10  GCA90    1415 non-null   object
#  11  Tkl+Int  1415 non-null   object
#  12  Blocks   1415 non-null   object
#  13  passes   1415 non-null   object
#  14  pass%    1415 non-null   object
#  15  CrsPA    1415 non-null   object
#  16  PPA      1415 non-null   object
# dtypes: int32(1), object(16)
# memory usage: 193.5+ KB

# %%
# convert metrics to int or float
players[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%']] = players[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%']].astype(float)
players[['PrgP', 'PrgC', 'PrgR', 'Tkl+Int', 'Blocks', 'passes', 'CrsPA', 'PPA']] = players[['PrgP', 'PrgC', 'PrgR', 'Tkl+Int', 'Blocks', 'passes', 'CrsPA', 'PPA']].astype(int)
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1415 entries, 0 to 1526
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   1415 non-null   object
#  1   Pos      1415 non-null   object
#  2   Min      1415 non-null   int32
#  3   90s      1415 non-null   float64
#  4   gls90    1415 non-null   float64
#  5   ast90    1415 non-null   float64
#  6   PrgP     1415 non-null   int32
#  7   PrgC     1415 non-null   int32
#  8   PrgR     1415 non-null   int32
#  9   SCA90    1415 non-null   float64
#  10  GCA90    1415 non-null   float64
#  11  Tkl+Int  1415 non-null   int32
#  12  Blocks   1415 non-null   int32
#  13  passes   1415 non-null   int32
#  14  pass%    1415 non-null   float64
#  15  CrsPA    1415 non-null   int32
#  16  PPA      1415 non-null   int32
# dtypes: float64(6), int32(9), object(2)
# memory usage: 149.2+ KB

# %%
# create the rest of our per90 metrics
players['prgp90'] = players['PrgP']/players['90s']
players['prgc90'] = players['PrgC']/players['90s']
players['prgr90'] = players['PrgR']/players['90s']
players['tkl+int90'] = players['Tkl+Int']/players['90s']
players['blocks90'] = players['Blocks']/players['90s']
players['passes90'] = players['passes']/players['90s']
players['crsPA90'] = players['CrsPA']/players['90s']
players['pPA90'] = players['PPA']/players['90s']


#drop all the variables we made a per 90 rate of
players = players.drop(['PrgP', 'PrgC', 'PrgR', 'Tkl+Int', 'Blocks', 'passes', 'CrsPA', 'PPA'], axis=1)

players.head()
# Out:
#               Player    Pos   Min   90s  gls90  ast90  SCA90  GCA90  pass%  \
# 0         Max Aarons     DF  1237  13.7   0.00   0.07   1.68   0.15   77.5
# 1   Brenden Aaronson  MF,FW  1267  14.1   0.14   0.14   3.76   0.57   77.3
# 2   Yunis Abdelhamid     DF  2781  30.9   0.13   0.00   0.78   0.03   84.5
# 3  Salis Abdul Samed     MF  1519  16.9   0.00   0.00   1.60   0.18   88.9
# 4    Laurent Abergel     MF  2860  31.8   0.06   0.03   2.55   0.16   84.5
#
#      prgp90    prgc90    prgr90  tkl+int90  blocks90   passes90   crsPA90  \
# 0  3.138686  1.605839  1.897810   2.700730  0.656934  32.846715  0.145985
# 1  3.971631  2.624113  6.453901   2.411348  1.843972  25.886525  0.212766
# 2  4.433657  1.165049  0.291262   3.333333  1.650485  50.226537  0.000000
# 3  4.615385  0.532544  1.183432   1.952663  0.710059  47.100592  0.118343
# 4  6.100629  1.194969  1.603774   4.591195  0.911950  48.773585  0.094340
#
#       pPA90
# 0  0.948905
# 1  0.992908
# 2  0.097087
# 3  0.295858
# 4  0.723270

# %%
# now our target variable is position, some of these players have multiple listed
# we will split so if a player has two positions, we take the first listed position

players[['primary_pos', 'secondary_pos']] = players['Pos'].str.split(",", n=1, expand=True)
players = players.drop(columns=['Pos', 'secondary_pos', 'Min'])
players.head()
# Out:
#               Player   90s  gls90  ast90  SCA90  GCA90  pass%    prgp90  \
# 0         Max Aarons  13.7   0.00   0.07   1.68   0.15   77.5  3.138686
# 1   Brenden Aaronson  14.1   0.14   0.14   3.76   0.57   77.3  3.971631
# 2   Yunis Abdelhamid  30.9   0.13   0.00   0.78   0.03   84.5  4.433657
# 3  Salis Abdul Samed  16.9   0.00   0.00   1.60   0.18   88.9  4.615385
# 4    Laurent Abergel  31.8   0.06   0.03   2.55   0.16   84.5  6.100629
#
#      prgc90    prgr90  tkl+int90  blocks90   passes90   crsPA90     pPA90  \
# 0  1.605839  1.897810   2.700730  0.656934  32.846715  0.145985  0.948905
# 1  2.624113  6.453901   2.411348  1.843972  25.886525  0.212766  0.992908
# 2  1.165049  0.291262   3.333333  1.650485  50.226537  0.000000  0.097087
# 3  0.532544  1.183432   1.952663  0.710059  47.100592  0.118343  0.295858
# 4  1.194969  1.603774   4.591195  0.911950  48.773585  0.094340  0.723270
#
#   primary_pos
# 0          DF
# 1          MF
# 2          DF
# 3          MF
# 4          MF

# %% [markdown]
# #### Performance Evaluation

# %%
# import libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %%
# create an 80-20 split of the data
np.random.seed(42)

players_train, players_test = train_test_split(
    players, train_size=0.80, stratify=players['primary_pos']
)

# %%
# check sizing
print(players_train.shape)
print(players_test.shape)
# Out:
# (1132, 16)
# (283, 16)

# %%
# initialize the classifier
knn = KNeighborsClassifier(n_neighbors=5)

# create the x and y variables
X = players_train[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']]
y = players_train['primary_pos']

# %%
# fit the knn model
knn.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
# now create predictions
players_test['predicted'] = knn.predict(players_test[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']])
players_test[['Player', 'primary_pos', 'predicted']]
# Out:
#                    Player primary_pos predicted
# 192        Josh Brownhill          MF        DF
# 231      Maxence Caqueret          MF        MF
# 856           Eric Martel          MF        MF
# 1393      Andros Townsend          MF        MF
# 845    Riccardo Marchizza          DF        DF
# ...                   ...         ...       ...
# 1304         Tomáš Souček          MF        MF
# 679           Reda Khadra          FW        FW
# 1015       Gerzino Nyamsi          DF        DF
# 576    Christophe Hérelle          DF        MF
# 436   Edimilson Fernandes          DF        DF
#
# [283 rows x 3 columns]

# %%
# score the predictions
knn.score(
    players_test[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']],
    players_test['primary_pos']
)
# Out:
# 0.7597173144876325

# %% [markdown]
# A 75.97% accuracy is not terrible, but I would like to crack 80-85%

# %%
# important an additional scoring option
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# the matrix of classifications
confusion_matrix(players_test['primary_pos'], players_test['predicted'])
# Out:
# array([[106,   2,  15],
#        [  3,  57,   6],
#        [ 34,   8,  52]], dtype=int64)

# %%
# classification score report
print(classification_report(players_test['primary_pos'], players_test['predicted']))
# Out:
#               precision    recall  f1-score   support
#
#           DF       0.74      0.86      0.80       123
#           FW       0.85      0.86      0.86        66
#           MF       0.71      0.55      0.62        94
#
#     accuracy                           0.76       283
#    macro avg       0.77      0.76      0.76       283
# weighted avg       0.76      0.76      0.75       283

# %% [markdown]
# Looks like the model is a bit weaker at classifying midfielders. Likely due to the fact midfield is a diversified pool of players. Some wingers may be classified as midfields, some defenders might be classified as midfielders.
#
# Overall, we have a fairly decent classification of players, in particular attackers. Maybe we can optimize the number of neighbors for the classification system.

# %%
# create grid of neighbours to select from
parameter_grid = {
    "n_neighbors": range(1, 50, 1)
}

# %%
# create the grid for the data to iterate through
pos_tune_grid = GridSearchCV(
    estimator = knn,
    param_grid=parameter_grid,
    cv=10 # we will run with 10 folds for now
)

# %%
# fit the model
pos_tune_grid.fit(
    players_train[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']],
    players_train['primary_pos']
)

accuracy_grid = pd.DataFrame(pos_tune_grid.cv_results_)
accuracy_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016533      0.004267         0.025771        0.005465
# 1        0.011842      0.000990         0.018221        0.001512
# 2        0.011054      0.001474         0.017862        0.001546
# 3        0.011129      0.001043         0.019040        0.001762
# 4        0.013448      0.002129         0.022125        0.003071
# 5        0.011056      0.000829         0.017706        0.000901
# 6        0.011023      0.000699         0.018695        0.001154
# 7        0.011137      0.000789         0.017833        0.001189
# 8        0.011577      0.001129         0.018416        0.001436
# 9        0.012076      0.001171         0.018358        0.001115
# 10       0.011785      0.000945         0.018770        0.001472
# 11       0.011637      0.000755         0.019467        0.001865
# 12       0.012141      0.001783         0.020810        0.002662
# 13       0.011232      0.001437         0.018118        0.000931
# 14       0.011078      0.001016         0.018579        0.001652
# 15       0.011840      0.001745         0.019136        0.002091
# 16       0.010989      0.000927         0.018476        0.000871
# 17       0.011707      0.001579         0.018607        0.001287
# 18       0.011042      0.000988         0.019161        0.001250
# 19       0.011663      0.001208         0.018968        0.000983
# 20       0.012353      0.001826         0.019490        0.002012
# 21       0.011138      0.001590         0.019455        0.001699
# 22       0.011443      0.001049         0.018566        0.000837
# 23       0.010991      0.000628         0.018837        0.001084
# 24       0.011601      0.001337         0.019102        0.001235
# 25       0.010817      0.001193         0.019839        0.002570
# 26       0.012782      0.001540         0.020603        0.001157
# 27       0.011576      0.001166         0.020133        0.002741
# 28       0.011712      0.002018         0.020271        0.002056
# 29       0.010751      0.000954         0.018458        0.001342
# 30       0.010826      0.001076         0.019711        0.001673
# 31       0.011613      0.001695         0.019874        0.000961
# 32       0.012165      0.001658         0.020338        0.001210
# 33       0.011622      0.002190         0.020317        0.001707
# 34       0.011580      0.001218         0.018982        0.001478
# 35       0.012933      0.002218         0.020778        0.002203
# 36       0.010950      0.001141         0.020845        0.001854
# 37       0.010749      0.001088         0.020294        0.001582
# 38       0.012148      0.002427         0.020999        0.002305
# 39       0.013023      0.001706         0.022440        0.002826
# 40       0.012304      0.001932         0.022098        0.002793
# 41       0.014014      0.001924         0.023849        0.004546
# 42       0.011611      0.001130         0.021547        0.002426
# 43       0.011454      0.001345         0.020737        0.001610
# 44       0.011867      0.001618         0.021629        0.002881
# 45       0.011894      0.000747         0.020815        0.001559
# 46       0.012648      0.002488         0.024054        0.003504
# 47       0.013012      0.001029         0.024185        0.002384
# 48       0.013507      0.002026         0.024399        0.003186
#
#     param_n_neighbors               params  split0_test_score  \
# 0                   1   {'n_neighbors': 1}           0.649123
# 1                   2   {'n_neighbors': 2}           0.684211
# 2                   3   {'n_neighbors': 3}           0.719298
# 3                   4   {'n_neighbors': 4}           0.719298
# 4                   5   {'n_neighbors': 5}           0.701754
# 5                   6   {'n_neighbors': 6}           0.719298
# 6                   7   {'n_neighbors': 7}           0.710526
# 7                   8   {'n_neighbors': 8}           0.728070
# 8                   9   {'n_neighbors': 9}           0.728070
# 9                  10  {'n_neighbors': 10}           0.736842
# 10                 11  {'n_neighbors': 11}           0.728070
# 11                 12  {'n_neighbors': 12}           0.710526
# 12                 13  {'n_neighbors': 13}           0.728070
# 13                 14  {'n_neighbors': 14}           0.719298
# 14                 15  {'n_neighbors': 15}           0.736842
# 15                 16  {'n_neighbors': 16}           0.745614
# 16                 17  {'n_neighbors': 17}           0.736842
# 17                 18  {'n_neighbors': 18}           0.754386
# 18                 19  {'n_neighbors': 19}           0.745614
# 19                 20  {'n_neighbors': 20}           0.771930
# 20                 21  {'n_neighbors': 21}           0.745614
# 21                 22  {'n_neighbors': 22}           0.736842
# 22                 23  {'n_neighbors': 23}           0.710526
# 23                 24  {'n_neighbors': 24}           0.771930
# 24                 25  {'n_neighbors': 25}           0.771930
# 25                 26  {'n_neighbors': 26}           0.754386
# 26                 27  {'n_neighbors': 27}           0.719298
# 27                 28  {'n_neighbors': 28}           0.728070
# 28                 29  {'n_neighbors': 29}           0.745614
# 29                 30  {'n_neighbors': 30}           0.736842
# 30                 31  {'n_neighbors': 31}           0.745614
# 31                 32  {'n_neighbors': 32}           0.745614
# 32                 33  {'n_neighbors': 33}           0.745614
# 33                 34  {'n_neighbors': 34}           0.771930
# 34                 35  {'n_neighbors': 35}           0.754386
# 38           0.778761           0.637168           0.734513         0.703159
# 39           0.787611           0.646018           0.743363         0.705845
# 40           0.787611           0.646018           0.761062         0.709354
# 41           0.769912           0.654867           0.743363         0.702298
# 42           0.787611           0.646018           0.725664         0.706699
# 43           0.778761           0.654867           0.743363         0.709377
# 44           0.778761           0.654867           0.743363         0.708485
# 45           0.778761           0.663717           0.743363         0.702329
# 46           0.787611           0.663717           0.734513         0.707600
# 47           0.778761           0.663717           0.743363         0.705845
# 48           0.778761           0.663717           0.743363         0.704068
#
#     std_test_score  rank_test_score
# 0         0.053280               27
# 1         0.035116               23
# 2         0.032539               10
# 3         0.039828                3
# 4         0.042409               12
# 5         0.020733                6
# 6         0.029424                2
# 7         0.033826                9
# 8         0.032289               11
# 9         0.043384               18
# 10        0.032596                5
# 11        0.035758                4
# 12        0.044224                1
# 13        0.046839               13
# 14        0.038295                8
# 15        0.044044               15
# 16        0.040021               14
# 17        0.034931               17
# 18        0.035073               19
# 19        0.043272               24
# 20        0.046344               20
# 21        0.039312               33
# 22        0.032341               37
# 23        0.042705               22
# 24        0.038361                7
# 25        0.038792               16
# 26        0.038273               26
# 27        0.037444               29
# 28        0.039823               21
# 29        0.039186               28
# 30        0.035120               31
# 31        0.033650               32
# 32        0.037237               35
# 33        0.040719               30
# 34        0.039447               39
# 35        0.043005               25
# 36        0.042481               45
# 37        0.043866               41
# 38        0.045587               47
# 39        0.047334               43
# 40        0.047720               35
# 41        0.045385               49
# 42        0.044609               42
# 43        0.044703               34
# 44        0.041802               38
# 45        0.046072               48
# 46        0.043366               40
# 47        0.040609               43
# 48        0.042967               46

# %% [markdown]
# Looks like 13 is the ideal number of neighbours. Let's perform a visual inspection of the neighbours.

# %%
# Create the plot
plt.figure(figsize=(10, 6))

# Plot mean test scores with error bars
plt.plot(accuracy_grid['param_n_neighbors'], accuracy_grid['mean_test_score'], '-o', color='blue')

# Add labels and legend
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy estimate')
plt.title('K-Nearest Neighbors Performance')
plt.tight_layout()
plt.show()

# %%
# extract the maximal k value
k=accuracy_grid[accuracy_grid['rank_test_score']==1]['param_n_neighbors'].values[0]
k
# Out:
# 13

# %%
print(f"Let's take a look at our final metrics from k={k}")
# Out:
# Let's take a look at our final metrics from k=13

# %%
knn = KNeighborsClassifier(n_neighbors = k)
X = players_train[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']]
y = players_train['primary_pos']

knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
# optimal metrics
optimal_acc = knn.score(players_test[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']],
                        players_test['primary_pos'])

print(f"The optimal accuracy of the classification model is {optimal_acc}.")
# Out:
# The optimal accuracy of the classification model is 0.7561837455830389.

# %%
# try the predicted optimal value
players_test['predicted'] = knn.predict(players_test[['90s', 'gls90', 'ast90', 'SCA90', 'GCA90', 'pass%', 'prgp90', 'prgc90', 'prgr90', 'tkl+int90', 'blocks90', 'passes90', 'crsPA90', 'pPA90']])
players_test[['Player', 'primary_pos', 'predicted']]
# Out:
#                    Player primary_pos predicted
# 192        Josh Brownhill          MF        DF
# 231      Maxence Caqueret          MF        MF
# 856           Eric Martel          MF        MF
# 1393      Andros Townsend          MF        FW
# 845    Riccardo Marchizza          DF        DF
# ...                   ...         ...       ...
# 1304         Tomáš Souček          MF        DF
# 679           Reda Khadra          FW        FW
# 1015       Gerzino Nyamsi          DF        DF
# 576    Christophe Hérelle          DF        MF
# 436   Edimilson Fernandes          DF        DF
#
# [283 rows x 3 columns]

# %% [markdown]
# Earlier, the accuracy score was 75.9%. Let's check to see if the classification report shows better results.

# %%
pd.crosstab(
    players_test['primary_pos'],
    players_test['predicted']
)
# Out:
# predicted     DF  FW  MF
# primary_pos
# DF           109   2  12
# FW             2  58   6
# MF            37  10  47

# %%
# classification report
print(classification_report(players_test['primary_pos'], players_test['predicted']))
# Out:
#               precision    recall  f1-score   support
#
#           DF       0.74      0.89      0.80       123
#           FW       0.83      0.88      0.85        66
#           MF       0.72      0.50      0.59        94
#
#     accuracy                           0.76       283
#    macro avg       0.76      0.75      0.75       283
# weighted avg       0.75      0.76      0.74       283

# %%
            precision    recall  f1-score   support

          DF       0.74      0.86      0.80       123
          FW       0.85      0.86      0.86        66
          MF       0.71      0.55      0.62        94

    accuracy                           0.76       283
   macro avg       0.77      0.76      0.76       283
weighted avg       0.76      0.76      0.75       283

# %% [markdown]
# It seems the tuning did not improve the parameter at all. Maybe our guess of 5 was particularly the best estimate for nearest neighbours.

# %%
players_test.head()
# Out:
#                   Player   90s  gls90  ast90  SCA90  GCA90  pass%    prgp90  \
# 192       Josh Brownhill  25.0   0.16   0.08   2.80   0.24   76.9  3.600000
# 231     Maxence Caqueret  33.6   0.03   0.09   3.37   0.21   82.7  8.511905
# 856          Eric Martel  27.3   0.04   0.04   1.58   0.11   81.1  2.747253
# 1393     Andros Townsend  13.4   0.07   0.22   2.68   0.45   70.4  2.611940
# 845   Riccardo Marchizza  12.8   0.00   0.31   1.10   0.31   75.8  2.812500
#
#         prgc90    prgr90  tkl+int90  blocks90   passes90   crsPA90     pPA90  \
# 192   0.760000  1.440000   3.800000  1.320000  34.000000  0.000000  0.640000
# 231   2.083333  2.857143   4.136905  1.190476  49.434524  0.208333  1.845238
# 856   0.769231  1.282051   4.139194  2.380952  33.443223  0.109890  0.219780
# 1393  3.507463  5.298507   1.940299  0.895522  22.686567  0.895522  1.194030
# 845   0.468750  3.046875   1.093750  0.781250  33.046875  0.390625  0.546875
#
#      primary_pos predicted
# 192           MF        DF
# 231           MF        MF
# 856           MF        MF
# 1393          MF        FW
# 845           DF        DF

# %%
# pre-process for a plot
plot_data = players_test[['primary_pos', 'predicted']]
plot_data['mismatch'] = np.where(plot_data['primary_pos'] == plot_data['predicted'], 0, 1)


plot_data = plot_data.value_counts(['primary_pos', 'mismatch']).reset_index()
plot_data.head()
# Out:
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_41764\3610465603.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data['mismatch'] = np.where(plot_data['primary_pos'] == plot_data['predicted'], 0, 1)
#   primary_pos  mismatch  count
# 0          DF         0    109
# 1          FW         0     58
# 2          MF         0     47
# 3          MF         1     47
# 4          DF         1     14

# %%
# create plot
plt.figure(figsize=(10,6))

# plot side by side
sns.catplot(
    data=plot_data,
    kind='bar',
    x='primary_pos',
    y='count',
    hue='mismatch'
)
plt.show()
